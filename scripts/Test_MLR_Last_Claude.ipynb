# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
import seaborn as sns

pathfile=r'/media/nicolascatz/ssdcalcul/Projets/CRPN_DTI_AGING_DPAKNC/'
pathfile=r'D:/DATA/Projets/CRPN_DTI_AGING_DPAKNC/'

pathdata=pathfile+'data/'
pathdata_tractography=pathfile+'data/Corrected_Tractometry2025'
pathcsv=pathfile+'CSV/'
pathfig=pathfile+'figures/'
os.chdir(pathfile)

addtotitle='_03022026_woMA_for_RD_MD_AD_FA' # to specify the version of the data
Aging_INDICES_all = pd.read_csv('Subject_preproc' + addtotitle + '.csv')
dataCC = pd.read_csv(pathdata+'/df_CC_long.csv', sep=',', index_col=0)
dataDTI = pd.read_csv(pathdata+'/Regions_CC_DTIvalues.csv', sep=',', index_col=0)


Aging_INDICES_all.head()
# Out:
#       sub  age group  JND_P  group_O  group_Y       IHD
# 0  sub-01   25     Y   9.56      0.0      1.0  0.534027
# 1  sub-02   27     Y   6.69      0.0      1.0  0.570600
# 2  sub-03   28     Y  12.92      0.0      1.0 -0.140120
# 3  sub-05   21     Y   1.95      0.0      1.0  0.488581
# 4  sub-06   25     Y   2.54      0.0      1.0  0.578001

# %%
dataCC.head()
# Out:
#        group region metric     value
# sub_id
# 0          Y   body     FA  0.583305
# 1          Y   body     FA  0.613541
# 2          Y   body     FA  0.627874
# 3          Y   body     FA  0.596940
# 4          Y   body     FA  0.637035

# %%
dataDTI.head()
# Out:
#          group  age sex  JND_P  JND_T       IHD   FA_body   AD_body   MD_body  \
# list_sub
# sub-01       Y   25   F   9.56   4.21  0.534027  0.583305  0.001200  0.000678
# sub-02       Y   27   M   6.69  11.62  0.570600  0.613541  0.001163  0.000638
# sub-03       Y   28   F  12.92   3.79 -0.140120  0.627874  0.001173  0.000631
# sub-05       Y   21   F   1.95   1.28  0.488581  0.596940  0.001187  0.000665
# sub-06       Y   25   F   2.54   2.22  0.578001  0.637035  0.001197  0.000636
#
#            RD_body   FA_genu   AD_genu   MD_genu   RD_genu  FA_splenium  \
# list_sub
# sub-01    0.000417  0.534531  0.001265  0.000769  0.000521     0.671109
# sub-02    0.000376  0.554182  0.001191  0.000711  0.000471     0.696520
# sub-03    0.000361  0.557587  0.001212  0.000710  0.000459     0.702712
# sub-05    0.000403  0.536202  0.001224  0.000736  0.000492     0.680835
# sub-06    0.000356  0.571072  0.001168  0.000674  0.000427     0.715834
#
#           AD_splenium  MD_splenium  RD_splenium
# list_sub
# sub-01       0.001202     0.000619     0.000327
# sub-02       0.001134     0.000571     0.000289
# sub-03       0.001195     0.000596     0.000296
# sub-05       0.001187     0.000607     0.000317
# sub-06       0.001239     0.000606     0.000290

# %%
dataDTI
# Out:
#          group  age sex    JND_P   JND_T       IHD   FA_body   AD_body  \
# list_sub
# sub-01       Y   25   F   9.5600   4.210  0.534027  0.583305  0.001200
# sub-02       Y   27   M   6.6900  11.620  0.570600  0.613541  0.001163
# sub-03       Y   28   F  12.9200   3.790 -0.140120  0.627874  0.001173
# sub-05       Y   21   F   1.9500   1.280  0.488581  0.596940  0.001187
# sub-06       Y   25   F   2.5400   2.220  0.578001  0.637035  0.001197
# sub-08       0.671470     0.001175     0.000608     0.000324
# sub-09       0.699339     0.001173     0.000586     0.000292
# sub-10       0.674281     0.001188     0.000611     0.000323
# sub-11       0.691902     0.001203     0.000606     0.000308
# sub-12       0.715063     0.001243     0.000608     0.000291
# sub-13       0.712000     0.001300     0.000637     0.000305
# sub-14       0.711723     0.001192     0.000589     0.000287
# sub-15       0.682954     0.001194     0.000609     0.000317
# sub-16       0.705568     0.001193     0.000594     0.000295
# sub-17       0.672483     0.001193     0.000615     0.000325
# sub-19       0.710792     0.001193     0.000589     0.000287
# sub-20       0.699785     0.001220     0.000609     0.000304
# sub-21       0.697441     0.001184     0.000594     0.000299
# sub-22       0.684858     0.001172     0.000596     0.000308
# sub-23       0.677746     0.001184     0.000605     0.000316
# sub-24       0.695060     0.001202     0.000605     0.000306
# sub-25       0.682561     0.001197     0.000609     0.000315
# sub-26       0.655853     0.001219     0.000638     0.000348
# sub-27       0.712529     0.001225     0.000603     0.000292
# sub-29       0.689441     0.001218     0.000615     0.000313
# sub-30       0.644263     0.001201     0.000637     0.000354
# sub-31       0.677831     0.001168     0.000601     0.000317
# sub-32       0.636809     0.001135     0.000608     0.000344
# sub-33       0.703187     0.001188     0.000592     0.000294
# sub-34       0.690028     0.001169     0.000592     0.000303
# sub-35       0.715901     0.001225     0.000601     0.000289
# sub-36       0.671967     0.001209     0.000625     0.000332
# sub-37       0.722536     0.001215     0.000590     0.000277
# sub-38       0.699869     0.001247     0.000621     0.000307
# sub-39       0.624849     0.001214     0.000659     0.000381
# sub-41       0.699350     0.001202     0.000601     0.000300
# sub-46       0.662214     0.001278     0.000666     0.000360
# sub-47       0.672013     0.001246     0.000640     0.000337
# sub-48       0.671980     0.001263     0.000650     0.000344
# sub-49       0.690787     0.001258     0.000633     0.000320
# sub-50       0.672249     0.001218     0.000627     0.000332
# sub-51       0.698911     0.001248     0.000624     0.000312

# %%
sns.scatterplot(data=dataDTI, x='JND_P', y='FA_genu', palette='tab10', legend=False)
# Out:
# C:\Users\Nicolas Catz\AppData\Local\Temp\ipykernel_38344\2744285137.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=dataDTI, x='JND_P', y='FA_genu', palette='tab10', legend=False)
# <Axes: xlabel='JND_P', ylabel='FA_genu'>

# %%
import statsmodels.api as sm

data_adjusted = dataDTI.copy()

X = sm.add_constant(data_adjusted['age'])
y = data_adjusted['FA_genu']
model = sm.OLS(y, X)

# Ajuster le modèle
results = model.fit()   

# Calculer les résidus
residuals = results.resid

# Mettre à jour les données DTI avec les résidus
data_adjusted = residuals

plt.scatter(dataDTI['age'], dataDTI['FA_genu'], label='Original Data')
plt.scatter(dataDTI['age'], data_adjusted, label='Adjusted Data (Residuals)', color='red')

# %% [markdown]
# ## Test d'association ajustée pour l'âge (version statistiquement correcte)
#
# La cellule précédente résidualise uniquement `FA_genu` pour l'âge puis (si on allait plus loin) la corrélerait avec `JND_P` brut — ce n'est valide pour une p-value que si `JND_P` est lui-même indépendant de l'âge. Ici on sépare :
# 1. **Inférence (p-value, coefficient)** : régression multiple jointe `FA_genu ~ JND_P + age` — c'est elle qui fait foi.
# 2. **Visualisation** : double résidualisation (Frisch-Waugh-Lovell) — `FA_genu` et `JND_P` sont chacun débarrassés de l'effet de l'âge avant d'être comparés, ce qui donne un partial regression plot cohérent avec le modèle joint.

# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt


def test_covariate_adjusted_association(df, outcome_col, covariate_col, predictor_col, plot=True):
    """Teste l'association outcome ~ predictor en controlant pour covariate.

    - joint_model : regression multiple outcome ~ predictor + covariate (fait foi pour la p-valeur)
    - les graphiques utilisent une double residualisation (Frisch-Waugh-Lovell) :
      outcome et predictor sont chacun debarrasses de l'effet de covariate avant d'etre compares,
      ce qui rend le partial regression plot coherent avec joint_model.
    """
    data = df[[outcome_col, covariate_col, predictor_col]].dropna()

    # 1) Regression jointe : seule source valide pour le coefficient/p-value de predictor_col
    X_full = sm.add_constant(data[[predictor_col, covariate_col]])
    joint_model = sm.OLS(data[outcome_col], X_full).fit()

    # 2) Double residualisation, uniquement pour la visualisation
    X_cov = sm.add_constant(data[covariate_col])
    outcome_resid = sm.OLS(data[outcome_col], X_cov).fit().resid
    predictor_resid = sm.OLS(data[predictor_col], X_cov).fit().resid

    if plot:
        fig, axs = plt.subplots(1, 2, figsize=(12, 5))

        axs[0].scatter(data[covariate_col], data[outcome_col], alpha=0.6, label='Donnees brutes')
        axs[0].scatter(data[covariate_col], outcome_resid, alpha=0.6, color='red', label='Residus (effet covariate retire)')
        axs[0].axhline(0, color='black', linestyle='--', linewidth=0.8)
        axs[0].set_xlabel(covariate_col)
        axs[0].set_ylabel(outcome_col)
        axs[0].set_title(f'{outcome_col} brut vs ajuste pour {covariate_col}')
        axs[0].spines['top'].set_visible(False)
        axs[0].spines['right'].set_visible(False)
        axs[0].legend()

        slope, intercept = np.polyfit(predictor_resid, outcome_resid, 1)
        line_x = np.linspace(predictor_resid.min(), predictor_resid.max(), 100)
        axs[1].scatter(predictor_resid, outcome_resid, alpha=0.6)
        axs[1].plot(line_x, slope * line_x + intercept, color='red')
        axs[1].axhline(0, color='black', linestyle='--', linewidth=0.8)
        axs[1].set_xlabel(f'{predictor_col} (ajuste pour {covariate_col})')
        axs[1].set_ylabel(f'{outcome_col} (ajuste pour {covariate_col})')
        axs[1].set_title('Partial regression plot (Frisch-Waugh-Lovell)')
     
        axs[1].spines['top'].set_visible(False)
        axs[1].spines['right'].set_visible(False)
        plt.tight_layout()
        plt.savefig(pathfig + f'Partial_regression_plot_{outcome_col}_vs_JND_P_adjusted_for_age.png', dpi=300)
        plt.show()

    print(f"--- Regression jointe : {outcome_col} ~ {predictor_col} + {covariate_col} ---")
    print(f"Coefficient {predictor_col} (effet partiel ajuste pour {covariate_col}) : {joint_model.params[predictor_col]:.4f}")
    print(f"P-valeur {predictor_col} : {joint_model.pvalues[predictor_col]:.4f}")
    print(f"Coefficient {covariate_col} : {joint_model.params[covariate_col]:.4f}")
    print(f"P-valeur {covariate_col} : {joint_model.pvalues[covariate_col]:.4f}")
    print(f"R-carre : {joint_model.rsquared:.3f}")

    return joint_model

outcome_col_list = ['FA_genu', 'FA_body', 'FA_splenium', 'MD_genu', 'MD_body', 'MD_splenium', 'RD_genu', 'RD_body', 'RD_splenium', 'AD_genu', 'AD_body', 'AD_splenium']
for outcome_col in outcome_col_list:
    joint_model = test_covariate_adjusted_association(
        dataDTI,
        outcome_col=outcome_col,
        covariate_col='age',
        predictor_col='JND_P',
    )
# Out:
# --- Regression jointe : FA_genu ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : -0.0000
# P-valeur JND_P : 0.9926
# Coefficient age : -0.0007
# P-valeur age : 0.0001
# R-carre : 0.492
# --- Regression jointe : FA_body ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : -0.0001
# P-valeur JND_P : 0.9155
# Coefficient age : -0.0005
# P-valeur age : 0.0050
# R-carre : 0.318
# --- Regression jointe : FA_splenium ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : -0.0013
# P-valeur JND_P : 0.1009
# Coefficient age : -0.0003
# P-valeur age : 0.0406
# R-carre : 0.381
# --- Regression jointe : MD_genu ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.1478
# Coefficient age : 0.0000
# P-valeur age : 0.0004
# R-carre : 0.558
# --- Regression jointe : MD_body ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.2151
# Coefficient age : 0.0000
# P-valeur age : 0.0868
# R-carre : 0.281
# --- Regression jointe : MD_splenium ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.5402
# Coefficient age : 0.0000
# P-valeur age : 0.1099
# R-carre : 0.183
# --- Regression jointe : RD_genu ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.2593
# Coefficient age : 0.0000
# P-valeur age : 0.0000
# R-carre : 0.614
# --- Regression jointe : RD_body ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.4054
# Coefficient age : 0.0000
# P-valeur age : 0.0094
# R-carre : 0.364
# --- Regression jointe : RD_splenium ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.1610
# Coefficient age : 0.0000
# P-valeur age : 0.0351
# R-carre : 0.359
# --- Regression jointe : AD_genu ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.0868
# Coefficient age : 0.0000
# P-valeur age : 0.0462
# R-carre : 0.383
# --- Regression jointe : AD_body ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : 0.0000
# P-valeur JND_P : 0.1600
# Coefficient age : -0.0000
# P-valeur age : 0.6766
# R-carre : 0.065
# --- Regression jointe : AD_splenium ~ JND_P + age ---
# Coefficient JND_P (effet partiel ajuste pour age) : -0.0000
# P-valeur JND_P : 0.6086
# Coefficient age : 0.0000
# P-valeur age : 0.7440
# R-carre : 0.007
